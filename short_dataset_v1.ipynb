# %%
import pandas as pd
with pd.HDFStore("train_cite_targets.h5", "r") as train:
    df=train.get("train_cite_targets")

# %%
len(df)
# Out:
# 70988

# %%
df.head()
# Out:
# gene_id           CD86     CD274     CD270     CD155     CD112      CD47  \
# cell_id
# 45006fe3e4c8  1.167804  0.622530  0.106959  0.324989  3.331674  6.426002
# d02759a80ba2  0.818970  0.506009  1.078682  6.848758  3.524885  5.279456
# c016c6b0efa5 -0.356703 -0.422261 -0.824493  1.137495  0.518924  7.221962
# ba7f733a4f75 -1.201507  0.149115  2.022468  6.021595  7.258670  2.792436
# fbcf2443ffb2 -0.100404  0.697461  0.625836 -0.298404  1.369898  3.254521
#
# gene_id            CD48      CD40     CD154      CD52  ...      CD94  \
# cell_id                                                ...
# 45006fe3e4c8   1.480766 -0.728392 -0.468851 -0.073285  ... -0.448390
# d02759a80ba2   4.930438  2.069372  0.333652 -0.468088  ...  0.323613
# c016c6b0efa5  -0.375034  1.738071  0.142919 -0.971460  ...  1.348692
# ba7f733a4f75  21.708519 -0.137913  1.649969 -0.754680  ...  1.504426
# fbcf2443ffb2  -1.659380  0.643531  0.902710  1.291877  ...  0.777023
#
# ...

# %%
train_df = df.head(1000)

# %%
train_df.to_csv('short_train_cite_targets.csv')

# %%
with pd.HDFStore("train_cite_inputs.h5", "r") as train:
    df=train.get("train_cite_inputs")
train_df = df.head(1000)
train_df.to_csv('short_train_cite_inputs.csv')

# %%
with pd.HDFStore("test_cite_inputs.h5", "r") as train:
    df=train.get("test_cite_inputs")
train_df = df.head(1000)
train_df.to_csv('short_test_cite_inputs.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 with pd.HDFStore("test_cite_targets.h5", "r") as train:
#       2     df=train.get("test_cite_targets")
#       3 train_df = df.head(1000)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:591, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     589 self._fletcher32 = fletcher32
#     590 self._filters = None
# --> 591 self.open(mode=mode, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/pytables.py:740, in HDFStore.open(self, mode, **kwargs)
#     734     msg = (
#     735         "Cannot open HDF5 file, which is already opened, "
#     736         "even in read-only mode."
#     737     )
#     738     raise ValueError(msg)
# --> 740 self._handle = tables.open_file(self._path, self._mode, **kwargs)
#
# ...
